# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

iris=pd.read_csv("C:\\Users\\Biancaa. R\\Downloads\\Iris.csv")
#iris=pd.read_csv(r"C:\Users\Biancaa. R\Downloads\Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info() #checking if the datatype matches
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.drop("Id",axis=1,inplace=True)

# %%
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
'''fig=iris[iris.Species=="Iris-setosa"].plot[kind='scatter', x ="SepalLengthCm", y ="SepalWidthCm", color = "orange", label = "Setosa"]

iris[iris.Species=="Iris-versicolor"].plot[kind="scatter",x="SepalLengthCm",y="SepalWidthCm",color="blue",label="Versicolor",ax=fig]

iris[iris.Species=="Iris-virginica"].plot[kind="scatter",x="SepalLengthCm",y="SepalWidthCm",color="green",label="Virginica",ax=fig]

'''
# Out:
# 'fig=iris[iris.Species=="Iris-setosa"].plot[kind=\'scatter\', x ="SepalLengthCm", y ="SepalWidthCm", color = "orange", label = "Setosa"]\n\niris[iris.Species=="Iris-versicolor"].plot[kind="scatter",x="SepalLengthCm",y="SepalWidthCm",color="blue",label="Versicolor",ax=fig]\n\niris[iris.Species=="Iris-virginica"].plot[kind="scatter",x="SepalLengthCm",y="SepalWidthCm",color="green",label="Virginica",ax=fig]\n\n'

# %%
#As we set ax=fig they all are added in the same figure

'''fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal length Vs Width")

fig=plt.gcf()
fig.set_size_inches(10,7)
plt.show()'''
# Out:
# 'fig.set_xlabel("Sepal Length")\nfig.set_ylabel("Sepal Width")\nfig.set_title("Sepal length Vs Width")\n\nfig=plt.gcf()\nfig.set_size_inches(10,7)\nplt.show()'

# %%
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='orange', label='Setoso')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='blue', label='Versicolor', ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm', color='green', label='Virginica', ax=fig)
fig.set_xlabel('Sepal Length')
fig.set_ylabel('Sepal Width')
fig.set_title('Sepal Length Vs Width')
fig=plt.gcf()
# where plt.gcf() means get the current figure.
fig.set_size_inches(10,7)
plt.show()

# %%
fig = iris[iris.Species == 'Iris-setosa'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='orange', label='Setoso')
iris[iris.Species == 'Iris-versicolor'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='blue', label='Versicolor', ax=fig)
iris[iris.Species == 'Iris-virginica'].plot(kind='scatter', x='PetalLengthCm', y='PetalWidthCm', color='green', label='Virginica', ax=fig)
fig.set_xlabel('Petal Length')
fig.set_ylabel('Petal Width')
fig.set_title('Petal Length Vs Width')
fig=plt.gcf()
# where plt.gcf() means get the current figure.
fig.set_size_inches(10,7)
plt.show()

# %%
iris.hist(edgecolor="black",linewidth=1.2,color="pink")
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()

#To see within what range most of the data lies

# %%
#y n plot
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x="Species",y="SepalLengthCm",data=iris)
plt.subplot(2,2,2)
sns.violinplot(x="Species",y="SepalWidthCm",data=iris)
plt.subplot(2,2,3)
sns.violinplot(x="Species",y="PetalLengthCm",data=iris)
plt.subplot(2,2,4)
sns.violinplot(x="Species",y="PetalWidthCm",data=iris)
#A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
from sklearn.linear_model import LogisticRegression
#linear model library
#logistic regression is the function
from sklearn.model_selection  import train_test_split#for splitting the data into test and train
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn import metrics #for checking the modal accuracy
from sklearn.tree import DecisionTreeClassifier

# %%
iris.shape
#Rows and columns
# Out:
# (150, 5)

# %%
#To see the intensity of the data
plt.figure(figsize=(8,4))
sns.heatmap(iris.corr(),annot=True,cmap="cubehelix_r")
plt.show()
# Out:
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\230019582.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),annot=True,cmap="cubehelix_r")

# %%
#splitiing the dataset to test and train data
train,test=train_test_split(iris,test_size=0.3)
print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 127            6.1           3.0            4.9           1.8   Iris-virginica
# 39             5.1           3.4            1.5           0.2      Iris-setosa
# 12             4.8           3.0            1.4           0.1      Iris-setosa
# 47             4.6           3.2            1.4           0.2      Iris-setosa
# 89             5.5           2.5            4.0           1.3  Iris-versicolor
# ..             ...           ...            ...           ...              ...
# 1              4.9           3.0            1.4           0.2      Iris-setosa
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 55             5.7           2.8            4.5           1.3  Iris-versicolor
# 59             5.2           2.7            3.9           1.4  Iris-versicolor
# 75             6.6           3.0            4.4           1.4  Iris-versicolor
#
# [105 rows x 5 columns]

# %%
train_x=train[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
train_y=train.Species
test_x=test[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
test_y=test.Species

# %%
train_y.head()
# Out:
# 127     Iris-virginica
# 39         Iris-setosa
# 12         Iris-setosa
# 47         Iris-setosa
# 89     Iris-versicolor
# Name: Species, dtype: object

# %%
test_x.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 42             4.4           3.2            1.3           0.2
# 83             6.0           2.7            5.1           1.6
# 79             5.7           2.6            3.5           1.0
# 144            6.7           3.3            5.7           2.5
# 73             6.1           2.8            4.7           1.2

# %% [markdown]
# model=LogisticRegression()
# model.fit(train_x,train_y)
# prediction=model.predict(test_x)
# print("The accuracy of logistic regression is",metrics.accuracy_score(prediction,test_y)

# %%
model=LogisticRegression()
model.fit(train_x,train_y) 
prediction=model.predict(test_x)#algorithm runs here
print("The accuracy of logistic regression is",metrics.accuracy_score(prediction,test_y))
# Out:
# The accuracy of logistic regression is 0.9333333333333333

# %%
x=iris.iloc[:,:-1].values
y=iris.iloc[:,-1].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=0)

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
#Logistic regression:

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

classifier=LogisticRegression()
classifier.fit(x_train,y_train)

y_pred=classifier.predict(x_test)

print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))

from sklearn.metrics import accuracy_score
print("The accuracy score is", accuracy_score(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.85      0.96      0.90        23
#  Iris-virginica       0.94      0.81      0.87        21
#
#        accuracy                           0.92        60
#       macro avg       0.93      0.92      0.92        60
#    weighted avg       0.92      0.92      0.92        60
#
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  4 17]]
# The accuracy score is 0.9166666666666666

# %%
#IF correct prediction
#recall - 
#fi score relation between precision,recall
#support is how many attributes used, we removed all independent variables

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report


classifier=DecisionTreeClassifier()
classifier.fit(x_train,y_train)

y_pred=classifier.predict(x_test)

print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))

from sklearn.metrics import accuracy_score
print("The accuracy score is", accuracy_score(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.92      0.96      0.94        23
#  Iris-virginica       0.95      0.90      0.93        21
#
#        accuracy                           0.95        60
#       macro avg       0.96      0.95      0.95        60
#    weighted avg       0.95      0.95      0.95        60
#
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  2 19]]
# The accuracy score is 0.95

# %%
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

classifier=SVC()
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))

from sklearn.metrics import accuracy_score
print("The accuracy score is", accuracy_score(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.88      0.96      0.92        23
#  Iris-virginica       0.95      0.86      0.90        21
#
#        accuracy                           0.93        60
#       macro avg       0.94      0.94      0.94        60
#    weighted avg       0.94      0.93      0.93        60
#
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  3 18]]
# The accuracy score is 0.9333333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

classifier=KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))


from sklearn.metrics import accuracy_score
print("The accuracy score is", accuracy_score(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        16
# Iris-versicolor       0.92      0.96      0.94        23
#  Iris-virginica       0.95      0.90      0.93        21
#
#        accuracy                           0.95        60
#       macro avg       0.96      0.95      0.95        60
#    weighted avg       0.95      0.95      0.95        60
#
# [[16  0  0]
#  [ 0 22  1]
#  [ 0  2 19]]
# The accuracy score is 0.95

# %%
a_index=range(1,11)
a=pd.Series()
for i in a_index:
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(train_x,train_y)
    pred_y=classifier.predict(test_x)
    accuracy_score=metrics.accuracy_score(pred_y,test_y)
    print(accuracy_score)
    a=a.append(pd.Series(accuracy_score))
plt.plot(a_index,a)
plt.xticks(a_index)
# Out:
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# 0.9777777777777777
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\3964826520.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   a=pd.Series()
# d:\Anaconda\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\3964826520.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# ...

# %%
a_index=range(1,11)
a=pd.Series()
for i in a_index:
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(x_train,y_train)
    pred_y=classifier.predict(x_test)
    accuracy_score=metrics.accuracy_score(y_pred,y_test)
    print(accuracy_score)
    a=a.append(pd.Series(accuracy_score))
plt.plot(a_index,a)
plt.xticks(a_index)
# Out:
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# 0.95
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\4048492330.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   a=pd.Series()
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\4048492330.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\4048492330.py:9: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# ...

# %%
a_index=range(1,11)
a=pd.Series()
for i in a_index:
    model=KNeighborsClassifier(n_neighbors=i)
    model.fit(train_x, train_y)
    prediction=model.predict(test_x)
    accuracy_score=metrics.accuracy_score(prediction,test_y)
    a=a.append(pd.Series(accuracy_score))
plt.plot(a_index,a)
plt.xticks(a_index)
# Out:
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\274400978.py:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   a=pd.Series()
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\274400978.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\274400978.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_20120\274400978.py:8: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a=a.append(pd.Series(accuracy_score))
# ...

# %%
### Creating Petals And Sepals Training Data
petal = iris[['PetalLengthCm','PetalWidthCm','Species']]
sepal = iris[['SepalLengthCm','SepalWidthCm','Species']]


### For Iris Petal
train_p,test_p = train_test_split(petal, test_size=0.3, random_state=0) #petals
train_x_p = train_p[['PetalWidthCm','PetalLengthCm']]
train_y_p = train_p.Species

test_x_p = test_p[['PetalWidthCm','PetalLengthCm']]
test_y_p = test_p.Species

### For Iris Sepal
train_s,test_s = train_test_split(sepal, test_size=0.3, random_state=0) #sepals
train_x_s = train_s[['SepalWidthCm','SepalLengthCm']]
train_y_s = train_s.Species

test_x_s = test_s[['SepalWidthCm','SepalLengthCm']]
test_y_s = test_s.Species

# %%
### SVM Algorithm

model=svm.SVC()
model.fit(train_x_p,train_y_p) 
prediction=model.predict(test_x_p) 
print('The accuracy of the SVM using Petals is:',metrics.accuracy_score(prediction,test_y_p))

model=svm.SVC()
model.fit(train_x_s,train_y_s) 
prediction=model.predict(test_x_s) 
print('The accuracy of the SVM using Sepals is:',metrics.accuracy_score(prediction,test_y_s))
# Out:
# The accuracy of the SVM using Petals is: 0.9777777777777777
# The accuracy of the SVM using Sepals is: 0.8

# %%
### Logistic Regression
model = LogisticRegression()
model.fit(train_x_p,train_y_p) 
prediction=model.predict(test_x_p) 
print('The accuracy of the Logistic Regression using Petals is:',metrics.accuracy_score(prediction,test_y_p))

model.fit(train_x_s,train_y_s) 
prediction=model.predict(test_x_s) 
print('The accuracy of the Logistic Regression using Sepals is:',metrics.accuracy_score(prediction,test_y_s))
# Out:
# The accuracy of the Logistic Regression using Petals is: 0.9777777777777777
# The accuracy of the Logistic Regression using Sepals is: 0.8222222222222222

# %%
### Decision Tree

model=DecisionTreeClassifier()
model.fit(train_x_p,train_y_p) 
prediction=model.predict(test_x_p) 
print('The accuracy of the Decision Tree using Petals is:',metrics.accuracy_score(prediction,test_y_p))

model.fit(train_x_s,train_y_s) 
prediction=model.predict(test_x_s) 
print('The accuracy of the Decision Tree using Sepals is:',metrics.accuracy_score(prediction,test_y_s))
# Out:
# The accuracy of the Decision Tree using Petals is: 0.9555555555555556
# The accuracy of the Decision Tree using Sepals is: 0.6666666666666666
