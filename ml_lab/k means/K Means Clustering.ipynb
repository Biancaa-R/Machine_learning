# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
from sklearn.datasets import make_blobs

# %%
# Create Data
data = make_blobs(n_samples=400, n_features=5,centers=3,cluster_std=2,random_state=20)

# %%
x=data[0][:,0]
y=data[0][:,1]
z=data[0][:,2]

# %%
data[1]
# Out:
# array([1, 2, 0, 2, 0, 2, 2, 2, 0, 0, 0, 2, 2, 2, 2, 0, 1, 0, 0, 0, 2, 2,
#        0, 1, 1, 2, 1, 1, 1, 2, 2, 1, 2, 1, 1, 1, 0, 2, 0, 1, 2, 1, 1, 1,
#        2, 0, 0, 0, 1, 1, 1, 0, 2, 1, 0, 0, 2, 0, 2, 0, 0, 1, 1, 1, 2, 1,
#        0, 1, 1, 2, 0, 1, 1, 0, 1, 1, 1, 0, 1, 2, 1, 1, 0, 1, 1, 1, 2, 0,
#        2, 1, 0, 0, 2, 2, 2, 1, 2, 1, 2, 1, 2, 2, 0, 0, 2, 1, 1, 2, 2, 1,
#        0, 0, 2, 0, 1, 2, 2, 2, 1, 0, 2, 1, 1, 1, 0, 0, 0, 1, 1, 1, 0, 2,
#        0, 1, 1, 2, 2, 0, 2, 1, 2, 0, 1, 1, 1, 0, 1, 1, 1, 2, 0, 0, 0, 2,
#        0, 2, 1, 2, 1, 2, 0, 0, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 1, 1, 1, 2,
#        0, 1, 1, 2, 0, 1, 2, 0, 2, 0, 0, 0, 1, 1, 0, 2, 1, 1, 0, 2, 1, 0,
#        0, 2, 0, 2, 0, 1, 2, 1, 0, 1, 1, 0, 2, 2, 1, 0, 1, 0, 0, 1, 0, 0,
#        2, 0, 1, 1, 0, 2, 2, 2, 0, 1, 2, 0, 2, 2, 0, 0, 2, 1, 2, 2, 2, 1,
#        1, 0, 0, 0, 2, 2, 2, 0, 2, 0, 1, 1, 2, 2, 0, 0, 1, 1, 2, 1, 2, 0,
#        0, 0, 2, 0, 2, 1, 2, 1, 0, 1, 0, 1, 1, 2, 0, 2, 0, 0, 1, 1, 2, 0,
# ...

# %%
pd.DataFrame(list(data[0]))
# Out:
#             0          1          2         3          4
# 0    1.850813   0.654035   0.460384  2.777395  -8.635410
# 1   -3.379123   5.906815   5.681221  7.029760   5.588130
# 2   -1.208572  11.385585   8.660906  7.033580 -14.075918
# 3   -0.522872   6.261416   4.424128  7.597583   3.276440
# 4    1.281335  11.837096   5.893806  8.062245  -7.213624
# ..        ...        ...        ...       ...        ...
# 395 -8.075451   0.164254   5.307204  7.674641   6.069576
# 396  3.364122   8.304245   6.540549  9.012299 -10.904367
# 397  3.540895   9.965094  12.084713  7.449322  -8.280542
# 398 -2.952089   4.720086   8.059490  5.752047   6.018002
# 399 -3.024173   2.983384   3.455747  7.246487   6.899051
#
# [400 rows x 5 columns]

# %%
fig = plt.figure(figsize = (9, 9))
ax = plt.axes(projection ="3d")
ax.scatter(data[0][:,0],data[0][:,1])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
centers=kmeans.cluster_centers_
labels=kmeans.labels_

# %%
labels
# Out:
# array([1, 0, 2, 0, 2, 0, 0, 0, 2, 2, 2, 0, 0, 0, 0, 2, 3, 2, 2, 2, 0, 0,
#        2, 1, 3, 0, 1, 1, 1, 0, 0, 1, 0, 3, 1, 3, 2, 0, 2, 3, 0, 3, 1, 1,
#        0, 2, 2, 2, 3, 3, 1, 2, 0, 3, 2, 2, 0, 2, 0, 2, 2, 1, 1, 1, 0, 1,
#        2, 3, 1, 0, 2, 1, 3, 2, 3, 1, 1, 2, 1, 0, 3, 3, 2, 1, 1, 1, 0, 2,
#        0, 1, 2, 2, 0, 0, 0, 3, 0, 1, 0, 3, 0, 0, 2, 2, 0, 3, 1, 0, 0, 3,
#        2, 2, 0, 2, 1, 0, 0, 0, 1, 2, 0, 3, 3, 1, 2, 2, 2, 1, 1, 3, 2, 0,
#        2, 1, 1, 0, 0, 2, 0, 1, 0, 2, 1, 3, 3, 2, 3, 3, 3, 0, 2, 2, 2, 0,
#        2, 0, 1, 0, 3, 0, 2, 2, 2, 0, 2, 0, 0, 2, 2, 0, 2, 2, 1, 3, 1, 0,
#        2, 3, 3, 0, 2, 3, 0, 2, 0, 2, 2, 2, 3, 3, 2, 0, 1, 3, 2, 0, 1, 2,
#        2, 0, 2, 0, 2, 1, 0, 1, 2, 3, 1, 2, 0, 0, 3, 2, 3, 2, 2, 1, 2, 2,
#        0, 2, 1, 1, 2, 0, 0, 0, 2, 1, 0, 2, 0, 0, 2, 2, 0, 1, 0, 0, 0, 3,
#        1, 2, 2, 2, 0, 0, 0, 2, 0, 2, 1, 3, 0, 0, 2, 2, 1, 3, 0, 3, 0, 2,
#        2, 2, 0, 2, 0, 3, 0, 1, 2, 1, 2, 3, 1, 0, 2, 0, 2, 2, 1, 3, 0, 2,
# ...

# %%
centers
# Out:
# array([[-4.15260528,  4.58357864,  5.63718639,  6.97002355,  5.37735469],
#        [ 3.72628064, -1.21573211,  0.19523176,  4.55873959, -7.35144369],
#        [ 1.55311749,  7.89271292,  7.90548405,  6.58057042, -9.39055575],
#        [ 3.89011497, -3.7012185 , -0.16371696,  2.62298487, -5.25426367]])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')#data after clustering it to 4 clusters
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')#dataset created for 3 clusters

# %% [markdown]
# For 2D dataset

# %%
data1 = make_blobs(n_samples=400, n_features=2,centers=3,cluster_std=2,random_state=20)

# %%
pd.DataFrame(list(data1[0]))
# Out:
#              0         1
# 0     7.362529  5.806004
# 1     1.936255  2.923566
# 2     1.793923  9.763595
# 3    -8.106487  6.953717
# 4    -0.374648  9.735709
# ..         ...       ...
# 395  10.291171  3.729313
# 396   5.865476  3.569477
# 397   2.749490  2.545544
# 398  -9.877437  4.142414
# 399   4.837904  5.891010
#
# [400 rows x 2 columns]

# %%
kmeans1 = KMeans(n_clusters=)

# %%
kmeans1.fit(data1[0])
# Out:
# KMeans(n_clusters=2)

# %%
centers1=kmeans1.cluster_centers_
labels1=kmeans1.labels_

# %%
centers1
# Out:
# array([[-9.55129773,  3.9630054 ],
#        [ 4.75763645,  7.28009887]])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data1[0][:,0],data1[0][:,1],c=kmeans1.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data1[0][:,0],data1[0][:,1],c=data1[1],cmap='rainbow')
