# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
social= pd.read_csv("..\lab-20250127T043012Z-001\lab\Social_Network_Ads_SVM.csv")
diab=pd.read_csv("..\lab-20250127T043012Z-001\lab\diabetes_logistic_regression.csv")
house=pd.read_csv("..\lab-20250127T043012Z-001\lab\kc_house_data.csv")
retail=pd.read_excel("..\lab-20250127T043012Z-001\lab\Online Retail_dta_visualisation.xlsx")
salary=pd.read_csv("../lab-20250127T043012Z-001\lab\Salary_Data_linear_regression.csv")

# %% [markdown]
# Barplot:

# %%
salary=social["EstimatedSalary"]
ids=social["User ID"]
#sales = [400, 350, 300, 450]
#sales=social["Purchased"]
plt.bar(ids,salary)
plt.title('')
plt.xlabel('IDs')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Distplot

# %%
plt.figure(figsize=(5,5))
sns.distplot(house['price'],bins=40,kde=False)
# Out:
# C:\Users\Biancaa. R\AppData\Local\Temp\ipykernel_18816\2812982124.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(house['price'],bins=40,kde=False)
# <Axes: xlabel='price'>
